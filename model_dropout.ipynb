# %% [markdown]
# # Image Classification on Pneumonia Chest Xray's with dropout in the fully connected layers

# %% [markdown]
# ### Steps
# - load and normalize data
#     - define transforms, dataset and dataloaders
#     - find mean and std
# - visualize images
# - define train function
# - define visualize function
# - define and freeze the model
# - define loss function and optimizer
# - train model
# - finetune the model
# - evaluate the model

# %%
# %matplotlib inline

# %%
from __future__ import print_function, division

# %%
import os
import copy 
import time
import numpy as np
import matplotlib.pyplot as plt

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.optim import lr_scheduler

# %%
import torchvision
from torchvision import transforms, datasets, models

# %%
plt.ion()

# %%
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
device
# Out:
# device(type='cuda', index=0)

# %% [markdown]
# ## load and normalize the data

# %%
transform = {
    'train': transforms.Compose([
        transforms.RandomResizedCrop(224),
        transforms.RandomHorizontalFlip(),
        transforms.ToTensor(),
        transforms.Normalize([0.5528, 0.5528, 0.5528], [0.1583, 0.1583, 0.1583])
    ]),
    'val': transforms.Compose([
        transforms.Resize(256),
        transforms.CenterCrop(224),
        transforms.ToTensor(),
        transforms.Normalize([0.5528, 0.5528, 0.5528], [0.1583, 0.1583, 0.1583])
    ]),
    'test': transforms.Compose([
        transforms.Resize(256),
        transforms.CenterCrop(224),
        transforms.ToTensor(),
        transforms.Normalize([0.5528, 0.5528, 0.5528], [0.1583, 0.1583, 0.1583])
    ])
}

# %%
path = './data/chest_xray/'

# %% [markdown]
# **datasets**

# %%
image_datasets = {x: datasets.ImageFolder(os.path.join(path, x), transform[x]) 
                  for x in ['train', 'val', 'test']}

# %% [markdown]
# **data loader**

# %%
data_loaders = {x: torch.utils.data.DataLoader(image_datasets[x], batch_size=1 if x == 'val' else 64, 
                                               shuffle=True, num_workers=4)
                for x in ['train', 'val', 'test']}

# %% [markdown]
# **number of images**

# %%
dataset_sizes = {x: len(image_datasets[x]) for x in ['train', 'val', 'test']}
dataset_sizes
# Out:
# {'test': 624, 'train': 5216, 'val': 16}

# %% [markdown]
# **classes**

# %%
class_names = image_datasets['train'].classes
class_names
# Out:
# ['NORMAL', 'PNEUMONIA']

# %% [markdown]
# **mean and std**

# %%
mean = 0.
std = 0.

# use large batch size just for finding mean and std
for images, labels in data_loaders['train']:
    images, labels = images.to(device), labels.to(device)
    
    # get number of images in the batch and number of channels
    batch_samples = images.size(0)
    nb_channels = images.size(1)
    # flatten height and width into one axis
    images = images.view(batch_samples, nb_channels, -1)
    # get mean and std
    mean += images.mean(2).sum(0)
    std += images.std(2).sum(0)
    
mean /= dataset_sizes['train']
std /= dataset_sizes['train']

print('mean: ', mean)
print('std: ', std)
# Out:
# mean:  tensor([-0.0079, -0.0079, -0.0079], device='cuda:0')
# std:  tensor([1.0030, 1.0030, 1.0030], device='cuda:0')

# %% [markdown]
# ## visualize some images

# %%
def imshow(img, title=None):
    # convert from tensor to numpy array
    inp = img.numpy().transpose((1, 2, 0))
    # mean and std used for normalization
    mean = np.array([0.5528, 0.5528, 0.5528])
    std = np.array([0.1583, 0.1583, 0.1583])
    # unnormalize
    inp = std * inp + mean 
    inp = np.clip(inp, 0, 1)
    
    plt.imshow(inp)
    if title is not None:
        plt.title(title)
    plt.pause(0.001)

# %%
train_iter = iter(data_loaders['train'])
images, labels = train_iter.next()

grid = torchvision.utils.make_grid(images)
title = [class_names[x] for x in labels]

imshow(grid, title=title)

# %% [markdown]
# ## define train function

# %%
def train(model, criterion, optimizer, scheduler, num_epochs=10):
    since = time.time()
    
    best_model_wts = copy.deepcopy(model.state_dict())
    best_acc = 0.
    
    for epoch in range(num_epochs):
        print('Epoch {}/{}'.format(epoch + 1, num_epochs))
        print('-' * 10)
        # each epoch has a training and a validation phase
        for phase in ['train', 'val']:
            if phase == 'train': 
                scheduler.step()
                model.train()
            else:
                model.eval()
                
            running_loss = 0.
            running_corrects = 0.
            # iterate over the images
            for images, labels in data_loaders[phase]:
                images, labels = images.to(device), labels.to(device)
                # zero the gradient parameters
                optimizer.zero_grad()
                
                # forward pass
                # track history if only in train
                with torch.set_grad_enabled(phase == 'train'):
                    outputs = model(images)
                    loss = criterion(outputs, labels)
                    _, preds = torch.max(outputs, 1)
                    
                    # backward + optimize if only in training 
                    if phase == 'train':
                        loss.backward()
                        optimizer.step()
                
                # stats 
                running_loss += loss.item() * labels.size(0)
                running_corrects += (preds == labels).sum().item()
            
            epoch_loss = running_loss / dataset_sizes[phase]
            epoch_acc = running_corrects / dataset_sizes[phase]
            
            print('{} Loss: {:.4f}  Acc: {:.4f}'.format(
                phase, epoch_loss, epoch_acc))
            
            if phase == 'val' and epoch_acc > best_acc:
                best_model_wts = copy.deepcopy(model.state_dict())
                best_acc = epoch_acc
        print()
        
    time_elapsed = time.time() - since
    print('Training complete in: {:.0f}m {:.0f}s'.format(
        time_elapsed // 60, time_elapsed % 60))
    print('Best validation acc: {:.4f}'.format(best_acc))
    # load best model weights
    model.load_state_dict(best_model_wts)
    return model

# %% [markdown]
# ### generic function to display predictions for a few images

# %%
def visualize_model(model, num_images=6):
    was_training = model.training
    images_so_far = 0
    model.eval()
    fig = plt.figure()
    
    with torch.no_grad():
        for images, labels in data_loaders['val']:
            images, labels = images.to(device), labels.to(device)
            
            outputs = model(images)
            _, preds = torch.max(outputs, 1)
            
            for j in range(images.size()[0]):
                images_so_far += 1
                ax = plt.subplot(num_images // 2, 2, images_so_far)
                ax.axis('off')
                ax.set_title('predicted: {}'.format(class_names[preds[j]]))
                imshow(images.cpu().data[j])
                
            if images_so_far == num_images:
                    model.train(mode=was_training)
                    return
        model.train(mode=was_training)

# %% [markdown]
# ## define and freeze model

# %% [markdown]
# **define new set of fully connected layers**

# %%
class FullyConnected(nn.Module):
    def __init__(self):
        super(FullyConnected, self).__init__()
        self.dropout = nn.Dropout(0.5)
        self.fc1 = nn.Linear(1000, 500)
        self.fc2 = nn.Linear(500, 2)
    
    def forward(self, x):
        x = self.dropout(x)
        x = self.dropout(self.fc1(x))
        x = self.fc2(x)
        return x

# %%
fully_connected = FullyConnected().to(device)

# %% [markdown]
# **pretrained model**

# %%
model_conv = torchvision.models.resnet34(pretrained=True)
model_conv = model_conv.to(device)

# %% [markdown]
# freeze weights

# %%
for param in model_conv.parameters():
    param.requires_grad = False

# %% [markdown]
# **combine pretrained and fc layers**

# %%
model = nn.Sequential(model_conv, fully_connected)

# %%
model = model.to(device)

# %% [markdown]
# ## define loss function

# %%
criterion = nn.CrossEntropyLoss()

# %% [markdown]
# ## define optimizer

# %%
optimizer = optim.Adam(model.parameters(), lr=0.001)

# %% [markdown]
# **define scheduler**

# %%
scheduler = lr_scheduler.StepLR(optimizer, step_size=7, gamma=0.1)

# %% [markdown]
# ## Train

# %%
model = train(model, criterion, optimizer, scheduler, num_epochs=25)
# Out:
# Epoch 1/25
# ----------
# train Loss: 0.4995  Acc: 0.8202
# val Loss: 1.4100  Acc: 0.5625
#
# Epoch 2/25
# ----------
# train Loss: 0.3504  Acc: 0.8512
# val Loss: 0.7433  Acc: 0.6875
#
# Epoch 3/25
# ----------
# train Loss: 0.3432  Acc: 0.8464
# val Loss: 1.3751  Acc: 0.5625
#
# Epoch 4/25
# ----------
# train Loss: 0.3274  Acc: 0.8650
# val Loss: 0.6117  Acc: 0.7500
#
# Epoch 5/25
# ----------
# train Loss: 0.3363  Acc: 0.8606
# val Loss: 0.8820  Acc: 0.6875
#
# Epoch 6/25
# ----------
# train Loss: 0.3309  Acc: 0.8637
# val Loss: 0.8719  Acc: 0.6875
#
# Epoch 7/25
# ----------
# train Loss: 0.3451  Acc: 0.8537
# val Loss: 0.6991  Acc: 0.7500
#
# Epoch 8/25
# ----------
# train Loss: 0.2954  Acc: 0.8721
# val Loss: 0.8604  Acc: 0.7500
#
# Epoch 9/25
# ----------
# train Loss: 0.2985  Acc: 0.8717
# val Loss: 0.8323  Acc: 0.6875
#
# Epoch 10/25
# ----------
# train Loss: 0.2952  Acc: 0.8756
# val Loss: 0.8881  Acc: 0.6875
#
# Epoch 11/25
# ----------
# train Loss: 0.2825  Acc: 0.8788
# val Loss: 0.8009  Acc: 0.7500
#
# Epoch 12/25
# ----------
# train Loss: 0.2899  Acc: 0.8714
# val Loss: 0.8033  Acc: 0.6875
#
# Epoch 13/25
# ----------
# train Loss: 0.2846  Acc: 0.8813
# val Loss: 0.9083  Acc: 0.6250
#
# Epoch 14/25
# ----------
# train Loss: 0.2803  Acc: 0.8748
# val Loss: 0.9937  Acc: 0.6250
#
# Epoch 15/25
# ----------
# train Loss: 0.2867  Acc: 0.8775
# val Loss: 0.8792  Acc: 0.6875
#
# Epoch 16/25
# ----------
# train Loss: 0.2887  Acc: 0.8767
# val Loss: 0.9468  Acc: 0.6250
#
# Epoch 17/25
# ----------
# train Loss: 0.2776  Acc: 0.8834
# val Loss: 0.8554  Acc: 0.6875
#
# Epoch 18/25
# ----------
# train Loss: 0.2855  Acc: 0.8756
# val Loss: 0.8960  Acc: 0.6875
#
# Epoch 19/25
# ----------
# train Loss: 0.2850  Acc: 0.8762
# val Loss: 0.8981  Acc: 0.6875
#
# Epoch 20/25
# ----------
# train Loss: 0.2911  Acc: 0.8729
# val Loss: 0.8854  Acc: 0.6875
#
# Epoch 21/25
# ----------
# train Loss: 0.2804  Acc: 0.8777
# val Loss: 0.8738  Acc: 0.6875
#
# Epoch 22/25
# ----------
# train Loss: 0.2866  Acc: 0.8777
# val Loss: 0.8985  Acc: 0.6875
#
# Epoch 23/25
# ----------
# train Loss: 0.2794  Acc: 0.8831
# val Loss: 0.8935  Acc: 0.6875
#
# Epoch 24/25
# ----------
# train Loss: 0.2900  Acc: 0.8719
# val Loss: 0.8999  Acc: 0.6875
#
# Epoch 25/25
# ----------
# train Loss: 0.2883  Acc: 0.8785
# val Loss: 0.8574  Acc: 0.6875
#
# Training complete in: 14m 40s
# Best validation acc: 0.7500

# %% [markdown]
# ## fine tuning

# %%
for param in model_conv.parameters():
    param.requires_grad = True

# %%
optimizer = optim.Adam(model.parameters(), lr=0.0001)

# %%
model = train(model, criterion, optimizer, scheduler, num_epochs=25)
# Out:
# Epoch 1/25
# ----------
# train Loss: 0.2242  Acc: 0.9122
# val Loss: 1.1846  Acc: 0.6250
#
# Epoch 2/25
# ----------
# train Loss: 0.1574  Acc: 0.9425
# val Loss: 1.3969  Acc: 0.6250
#
# Epoch 3/25
# ----------
# train Loss: 0.1401  Acc: 0.9469
# val Loss: 0.2934  Acc: 0.8125
#
# Epoch 4/25
# ----------
# train Loss: 0.1367  Acc: 0.9500
# val Loss: 0.4403  Acc: 0.6875
#
# Epoch 5/25
# ----------
# train Loss: 0.1145  Acc: 0.9551
# val Loss: 0.2185  Acc: 0.9375
#
# Epoch 6/25
# ----------
# train Loss: 0.1270  Acc: 0.9544
# val Loss: 0.4241  Acc: 0.7500
#
# Epoch 7/25
# ----------
# train Loss: 0.1039  Acc: 0.9584
# val Loss: 0.6377  Acc: 0.6250
#
# Epoch 8/25
# ----------
# train Loss: 0.0984  Acc: 0.9624
# val Loss: 0.1302  Acc: 0.9375
#
# Epoch 9/25
# ----------
# train Loss: 0.1048  Acc: 0.9611
# val Loss: 0.5376  Acc: 0.6875
#
# Epoch 10/25
# ----------
# train Loss: 0.0960  Acc: 0.9634
# val Loss: 0.0620  Acc: 1.0000
#
# Epoch 11/25
# ----------
# train Loss: 0.0900  Acc: 0.9655
# val Loss: 0.3015  Acc: 0.8750
#
# Epoch 12/25
# ----------
# train Loss: 0.0853  Acc: 0.9695
# val Loss: 0.8176  Acc: 0.6250
#
# Epoch 13/25
# ----------
# train Loss: 0.0875  Acc: 0.9653
# val Loss: 0.6061  Acc: 0.6250
#
# Epoch 14/25
# ----------
# train Loss: 0.0942  Acc: 0.9641
# val Loss: 0.2874  Acc: 0.8750
#
# Epoch 15/25
# ----------
# train Loss: 0.0810  Acc: 0.9701
# val Loss: 0.7263  Acc: 0.7500
#
# Epoch 16/25
# ----------
# train Loss: 0.0739  Acc: 0.9764
# val Loss: 0.3511  Acc: 0.8125
#
# Epoch 17/25
# ----------
# train Loss: 0.0823  Acc: 0.9693
# val Loss: 1.2639  Acc: 0.6250
#
# Epoch 18/25
# ----------
# train Loss: 0.0822  Acc: 0.9697
# val Loss: 0.3901  Acc: 0.7500
#
# Epoch 19/25
# ----------
# train Loss: 0.0731  Acc: 0.9730
# val Loss: 1.0230  Acc: 0.6250
#
# Epoch 20/25
# ----------
# train Loss: 0.0740  Acc: 0.9741
# val Loss: 1.8894  Acc: 0.5000
#
# Epoch 21/25
# ----------
# train Loss: 0.0749  Acc: 0.9705
# val Loss: 0.6775  Acc: 0.7500
#
# Epoch 22/25
# ----------
# train Loss: 0.0786  Acc: 0.9688
# val Loss: 1.2114  Acc: 0.6250
#
# Epoch 23/25
# ----------
# train Loss: 0.0690  Acc: 0.9714
# val Loss: 1.2009  Acc: 0.6250
#
# Epoch 24/25
# ----------
# train Loss: 0.0635  Acc: 0.9741
# val Loss: 0.5606  Acc: 0.7500
#
# Epoch 25/25
# ----------
# train Loss: 0.0743  Acc: 0.9726
# val Loss: 0.3092  Acc: 0.8750
#
# Training complete in: 15m 5s
# Best validation acc: 1.0000

# %% [markdown]
# ## evaluate

# %%
correct = 0 
total = 0

with torch.no_grad():
    for images, labels in data_loaders['test']:
        images, labels = images.to(device), labels.to(device)
        
        outputs = model(images)
        _, preds = torch.max(outputs, 1)
        
        total += labels.size(0)
        correct += (preds == labels).sum().item()
        
acc = (correct / total) * 100
print('Test accuracy: {:.2f}%'.format(acc))
# Out:
# Test accuracy: 95.03%

# %%
visualize_model(model)
